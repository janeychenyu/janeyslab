# %%
1+1
# Out:
# 2

# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
plt.plot([3,-5,2,7,10,-9])

# %%
y= [3,-5,2,7,10,-9]

# %%
plt.plot(y)

# %%
x=[0,0.7,1,2,7,9]

# %%
y
# Out:
# [3, -5, 2, 7, 10, -9]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %% [markdown]
# # 大標題
# ## 第二大標題
# 內文
#
# [Pythonn課程]

# %% [markdown]
# ![圖](CEO.png)

# %%
假設我們有函數 $f(x)=x^3-2x^2+5$
# Out:
#   File "<ipython-input-18-720803b9c599>", line 1
#     假設我們有函數 $f(x)=x^3-2x^2+5$
#             ^
# SyntaxError: invalid syntax

# %%
x= np.linspace(-100,100,500000000)

# %%
y=np.cos(x)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
# Out:
#   File "<ipython-input-29-8139c3c3f3b1>", line 1
#     plt.plot[sqrt(​cos(​x))*​cos(​200*​x)+​sqrt(​abs(​x))-​0.7)*​(4-​x*​x)^​0.01, sqrt(​9-​x^​2), ‑sqrt(​9-​x^​2)]
#                      ^
# SyntaxError: invalid character in identifier

# %%
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """Entry point for launching an IPython kernel.

# %%
# Out:
#   File "<ipython-input-33-68d4b1af4494>", line 1
#     y=np.[sqrt(cos(x))*cos(200*x)+sqrt[(abs(x))-0.7]*(4-x*x)^0.01, sqrt(9-x^2), ‑sqrt(9-x^2)]
#          ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d8b592bf313e> in <module>
# ----> 1 plt.plot(x,y)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...
