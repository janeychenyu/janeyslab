# %%
1+1
# Out:
# 2

# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
plt.plot([3,-5,2,7,10,-9])

# %%
y= [3,-5,2,7,10,-9]

# %%
plt.plot(y)

# %%
x=[0,0.7,1,2,7,9]

# %%
y
# Out:
# [3, -5, 2, 7, 10, -9]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %% [markdown]
# # 大標題
# ## 第二大標題
# 內文
#
# [Pythonn課程]

# %% [markdown]
# ![圖](CEO.png)

# %%
假設我們有函數 $f(x)=x^3-2x^2+5$
# Out:
#   File "<ipython-input-18-720803b9c599>", line 1
#     假設我們有函數 $f(x)=x^3-2x^2+5$
#             ^
# SyntaxError: invalid syntax

# %%
x= np.linspace(0,1,50)

# %%
y=np.cos(x)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)
